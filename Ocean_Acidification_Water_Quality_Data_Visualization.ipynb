# %% [markdown]
# # Ocean Acidification Water Quality Data Visualization

# %% [markdown]
# ## Contents
# 1. File Directory
#     - Explain contents and location of folders
#         - Folders are created based on data type: pCO2, pH, conductivity,...
#         - Files located in same place with program are graphed & is the compiled version from raw data
#         - Graphs saved in _Data__Graphs folder
# 2. Data Processing
#     - pCO2 Data Files (specify location in repository)
#         - Downloading of files from SAMI
#         - Data processing done
#             - Outlier removal based on month
#                 - Used IQR
#             - Analysis of normality of data
#                 - Include histograms
#             - Data Scaling
#                 - Discuss methods
#     - Weather Data Files (specify location in repository)
#         - Analysis of data sources
#             - Wunderground chosen
#         - Downloading of files from Wunderground
#             - Steps taken
#     - Tidal Data Files (specify location in repository)
#         - Downloading of data from NOAA
#             - Steps taken
#     - pH Data Files (specify location in repository)
#         - Downloading of files from SAMI
#     - Salinity Data Files (specify location in repository)
#         - Steps taken
#         - Data Processing Done
#             - Comparison with salinity data from research paper
#                 - Explain trends found in paper vs our data
#                 - Remove 12% updrift/downdrift every 30 days from start to end period
#     - Castaway Data (specify location in repository)
#         - Downloading of files
#         - Data Processing Done
#             - Use depth measurement closest to 1.5 m
# 3. Steps for Graphing
#     - 1. Download data accordingly
#     - 2. Use file concatenator program in repository
#         - Explain limitations of the program
#         - Explain program versions
#             - Automated vs Unautomated
#     - 3. Input data file name in specified areas of appropriate graphing program & update graph titles
#     - 4. Run
#         - Files automatically save to folder based on data type
# 4. Data Analysis
#     - Battery vs. CO2 Plot
#         - No major influence of battery levels on CO2 measurements
#     - GPR on Weather, pCO2, and Tidal for 2021
#         - Explain process
#         - Include results
# 5. Concatenation Information
#     - Program used to concatenate all data files into one universal directory
#     - Steps on how to use the program
#         - File formatting

# %% [markdown]
# ## **Table of Contents**
# ***
# 1. **File Directory**
#     - 1.1 General Overview
#     - 1.2 Folders & Subfolders Contents
# #
# 2. **Data Processing**
#     - 2.1 General Overview
#     - 2.2 pCO2 Data
#     - 2.3 Weather Data
#     - 2.4 Tidal Data
#     - 2.5 pH Data
#     - 2.6 Conductivity Data
#     - 2.7 Castaway Data
# #
# 3. **Graphing Instructions**
#     - 3.1 pCO2
#     - 3.2 pH
#     - 3.3 Conductivity
# #
# 4. **Data Analysis**
#     - 4.1 Battery vs. CO2 Plot
#     - 4.2 Gaussian Process Regression (GPR) on 2021 Weather, pCO2, and Tidal Data
# #
# 5. **Concatenation Information**
# #
# ***

# %% [markdown]
# #

# %% [markdown]
# ## **1. File Directory**
# ***
# ### **1.1 General Overview**
# Folders contain subfolders containing relevant content for category (e.g. Data Files, Graphing Program, Graph Output)
# #
# ### **1.2 Folders & Subfolders Contents**
# Directory presented in the form:
# - Folder: Summary of items not in subfolder
#     - Subfolder: Summary of contents
# #
# **Repository:** SEAGRANT_OA_WQ_Data_Visualization
# - **Data_Formatting**: Contains programs used to concat data files together for graphing in grapher programs or data processing
# #
# - **pCO2:** Contains pCO2 graphers that graphs both pCO2 and sourced data, extracts outliers based on an annual interval, and extracts based on a monthly interval
#     - **pCO2_Data:** Contains concatted pCO2 data for 2021-2023
#     - **pCO2_graphs:** Contains .png of graphs from pCO2 graphing programs
#     - **pCO2_Raw_Data:** Contains subfolders containing unconcatted data pCO2 files from 2021-2023
#     - **Sourced Data:** Contains data not obtained by MIT Sea Grant sensors used for graphing
#         - **Salinity:** Contains salinity data on Fiddler's Cove, MA from 1992-2020 sourced from Nature article
#         - **Tidal:** Contains files used for graphing tidal plot in pCO2 grapher program
#             - **Compiled_Tidal_Data:** Contains concatted data for Wood's Hole, MA taken every 6 mins and highs/lows for every day
#             - **Raw_Tidal_Data:** Contains subfolders containing unformatted tidal data from Wood's Hole, MA taken every 6 mins and highs/lows for every day
#         - **Weather:** Contains data files from 2021 in Barlow's Landing, MA used in pCO2 grapher program
# #
# - **pH:** Contains pH programs that takes out outliers based on monthly intervals and annual intervals and concatted data for each year used for graphing
#     - **pH_Graphs:** Conatins .png of graphs from pH graphing programs
#     - ***pH_Raw_Data:** Contains subfolders containing unconcatted pH data for each year
# #
# - **Conductivity:** Contains salinity_data_grapher.py (graphing program), and data files used for graphing
#     - **Conductivity_Graphs:** Contains .png of graphs from salinity_data_grapher.py
# #
# - **MWRA_Data:** Contains raw data files of upcasts and downcasts
# #
# - **Analysis:** Contains graphing program plotting pCO2 vs. Battery for 2021, graph image, and data file
# #
# - **Developmental_Tests:** Contains early version of programs (that can be discarded) within repository
# #
# #
# #
# **Note: Graphs produced in programs are automatically saved in "Data Type"_Graphs subfolder**
# ***

# %% [markdown]
# #

# %% [markdown]
# ## **2. Data Processing**
# ***
# ### **2.1 General Overview**
# Outlier removers are located within graphing programs for pCO2 and pH. The conductivity outlier remover is still in development.
# #
# ### **2.2 pCO2 Data**
# **Verdict: IQR was used to remove outliers from data on a monthly interval.**
# #
# To determine on what interval (annual or monthly) to remove outliers from pCO2 data, a comparison was done between both methods of removing outliers. It was determined that the results produced from both methods were similar, so we decieded to use a monthly time scale as pCO2 has known periodical changes.
# #
# ### **2.3 Weather Data**
# #
# ### **2.4 Tidal Data**
# #
# ### **2.5 pH Data**
# **Verdict: IQR was used to remove outliers from data on a monthly interval.**
# #
# ### **2.6 Conductivity Data**
# Outlier remover is in development
# #
# ### **2.7 Castaway Data**
# TBD
# #
# Possibly need new folder to store raw data files and program for processing data
# #
# ***

# %% [markdown]
# #

# %% [markdown]
# ## **3. Graphing Instructions**
# ***
# ### **3.1 pCO2**
# #
# ### **3.2 pH**
# #
# ### **3.3 Conductivity**
# #
# ***

# %% [markdown]
# #

# %% [markdown]
# ## **4. Data Analysis**
# ***
# ### **4.1 Battery vs. CO2 Plot**
# #
# ### **4.2 Gaussian Process Regression (GPR) on 2021 pCO2, Weather, and Tidal Data**
# #
# ***

# %% [markdown]
# #

# %% [markdown]
# ## **5. Concatenation Information**
# ***
# TBD

# %% [markdown]
# # Grapher

# %% [markdown]
# The grapher code is suited for graphing the concatenated data file produced by the "Looped File Merger".
#
# Specifications for concatenated data file:
# -> Data must be in chronological order from oldest to newest (top to bottom).
# -> Data must only have 4 columns (Year Day, Temperature (C), CO2, and Battery Voltage)
# -> Data dates are specific to non-leap years.
# -> Data must be in CSV file format.
#
# Otherwise, the program below must be tweaked to allow for other entries.

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
import csv
import math


# Sets the graph layout colors and style
plt.style.use('default')

# Used to hold data from csv file  
x = []      # Dates
ty = []     # Temperature
cy = []     # CO2
by = []     # Battery Voltage

numofLines = 0
 
with open('C:\\Users\\isabe\\Source\\Repos\\icyeung\\pCO2-DataTrue\\pCO2_data\\completeData.csv','r') as csvfile:
    lines = csv.reader(csvfile, delimiter='\t')
    for row in lines:
        
        # Checks if time entry has corresponding Temperature, CO2, and Battery Voltage
        # If not, does not include data point in graph
        if not row[1] == "" and not row[2] == "" and not row[3] == "" and numofLines > 0:
            x.append(float(row[0]))
            ty.append(float(row[1]))
            cy.append(float(row[2]))
            by.append(float(row[3]))
            numofLines += 1
        elif numofLines == 0:
            numofLines += 1

# Makes graph wider so Dates can be viewed properly
plt.figure().set_figwidth(60)

# Allows for more than one set of data to be plotted

# Temperature plot
fig, ax1 = plt.subplots()
p1 = ax1.plot(x, ty, color = 'b', linestyle = 'solid', label = "Temperature (C)")

# Sets x-axis as Dates
ax1.xaxis.set_ticks(np.arange(math.trunc(x[0]), math.trunc(x[-1]), 1))     # Step size of 1
ax1.set_xticklabels(ax1.get_xticks(), rotation = 90)        # Rotates dates to be perpendiculat to x-axis

# Sets axis labels and changes font color for easy viewing
ax1.set_ylabel("Temperature (C)")
ax1.set_xlabel("Dates")
ax1.yaxis.label.set_color(p1[0].get_color())


# CO2 plot
ax2 = ax1.twinx()
p2 = ax2.plot(x, cy, color = 'r', linestyle = 'solid', label = "CO2")
ax2.set_ylabel("CO2")
ax2.yaxis.label.set_color(p2[0].get_color())

# Battery Voltage plot
ax3 = ax1.twinx()
p3 = ax3.plot(x, by, color = 'g', linestyle = 'solid', label = "Battery Voltage")
ax3.set_ylabel("Battery Voltage")
ax3.spines["right"].set_position(("outward", 60))
ax3.yaxis.label.set_color(p3[0].get_color())

  
# Sets title, adds a grid, and shows legend
plt.title('pCO2 Data', fontsize = 20)
plt.grid(True)
plt.legend(handles=p1+p2+p3)

plt.show()

# %% [markdown]
# # Grapher Result

# %% [markdown]
# Will result in graph as shown above.
#
# -> It is best to extend the graph horizaontally and choose "Tight fit" for best viewing.
# -> If possible, dual monitor display will allow for a comfortable viewing.
